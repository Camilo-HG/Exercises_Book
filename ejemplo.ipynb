# %%
import numpy as np

# %%
suma = {}

for x in np.linspace(0,10,15):
    for y in np.linspace(0,10,20):
        for z in np.linspace(0,10,30):
               suma[x, y, z] = x + y + z

# %%
x = np.linspace(0,10,15)
y = np.linspace(0,10,20)
z = np.linspace(0,10,30)

# %%
suma[x[0], y[1], z[0]]
# Out:
# 0.5263157894736842

# %%
y[1]
# Out:
# 0.5263157894736842

# %%
suma
# Out:
# {(10.0, 4.2105263157894735, 2.7586206896551726): 16.969147005444647,
#  (0.7142857142857143,
#   1.5789473684210527,
#   7.931034482758621): 10.224267565465388,
#  (2.142857142857143,
#   0.5263157894736842,
#   8.275862068965518): 10.945035001296345,
#  (5.0, 5.263157894736842, 7.931034482758621): 18.19419237749546,
#  (4.285714285714286, 10.0, 5.862068965517242): 20.147783251231527,
#  (9.285714285714286, 8.947368421052632, 8.620689655172415): 26.853772361939335,
#  (4.285714285714286, 7.368421052631579, 6.206896551724139): 17.861031890070002,
#  (8.571428571428571,
#   1.5789473684210527,
#   9.655172413793103): 19.805548353642727,
#  (10.0, 3.1578947368421053, 3.793103448275862): 16.950998185117967,
#  (7.142857142857143,
#   3.6842105263157894,
#   7.586206896551724): 18.413274565724656,
#  (1.4285714285714286,
#   4.7368421052631575,
#   2.0689655172413794): 8.234379051075965,
#  (7.142857142857143, 1.0526315789473684, 1.3793103448275863): 9.5747990666321,
# ...
